# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fish-dataset/fish dataset.csv

# %% [markdown]
# # Libraies importing

# %%
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Data

# %%
data = pd.read_csv("/kaggle/input/fish-dataset/fish dataset.csv")

# %%
data
# Out:
#       Fish Name  Fish count
# 0     Gold Fish           7
# 1    Angel Fish          11
# 2     Glow Fish          13
# 3       Guppies          16
# 4  Rainbow Fish          18
# 5    Molly Fish          22
# 6        Tetra           24

# %%
data.describe().round(2)
# Out:
#        Fish count
# count        7.00
# mean        15.86
# std          6.04
# min          7.00
# 25%         12.00
# 50%         16.00
# 75%         20.00
# max         24.00

# %% [markdown]
# ### Standardization

# %%
scaler = StandardScaler()

# %%
data
# Out:
#       Fish Name  Fish count
# 0     Gold Fish           7
# 1    Angel Fish          11
# 2     Glow Fish          13
# 3       Guppies          16
# 4  Rainbow Fish          18
# 5    Molly Fish          22
# 6        Tetra           24

# %%
data['Fish count'].values
# Out:
# array([ 7, 11, 13, 16, 18, 22, 24])

# %%
data['Fish count'].values.reshape(-1,1)
# Out:
# array([[ 7],
#        [11],
#        [13],
#        [16],
#        [18],
#        [22],
#        [24]])

# %%
standard_values = scaler.fit(data['Fish count'].values.reshape(-1,1))

# %%
standard_values
# Out:
# StandardScaler()

# %%
scaled_fish_count = scaler.transform(data['Fish count'].values.reshape(-1,1))

# %%
scaled_fish_count
# Out:
# array([[-1.584026  ],
#        [-0.86865942],
#        [-0.51097613],
#        [ 0.02554881],
#        [ 0.3832321 ],
#        [ 1.09859868],
#        [ 1.45628197]])

# %%
data['scaled fish count'] = scaled_fish_count

# %%
data.describe().round(2)
# Out:
#        Fish count  scaled fish count
# count        7.00               7.00
# mean        15.86              -0.00
# std          6.04               1.08
# min          7.00              -1.58
# 25%         12.00              -0.69
# 50%         16.00               0.03
# 75%         20.00               0.74
# max         24.00               1.46

# %%
data['Fish count'].values.reshape(-1,1)
# Out:
# array([[ 7],
#        [11],
#        [13],
#        [16],
#        [18],
#        [22],
#        [24]])

# %% [markdown]
# # Normalization

# %%
scaler2 = MinMaxScaler()

# %%
minmaxer = scaler2.fit(data['Fish count'].values.reshape(-1,1))

# %%
minmaxer
# Out:
# MinMaxScaler()

# %%
scaled_fish_count2 = scaler2.transform(data['Fish count'].values.reshape(-1,1))

# %%
scaled_fish_count2
# Out:
# array([[0.        ],
#        [0.23529412],
#        [0.35294118],
#        [0.52941176],
#        [0.64705882],
#        [0.88235294],
#        [1.        ]])

# %%
data['scaled_fish_count_2'] = scaled_fish_count2

# %%
data.describe().round(2)
# Out:
#        Fish count  scaled fish count  scaled_fish_count_2
# count        7.00               7.00                 7.00
# mean        15.86              -0.00                 0.52
# std          6.04               1.08                 0.36
# min          7.00              -1.58                 0.00
# 25%         12.00              -0.69                 0.29
# 50%         16.00               0.03                 0.53
# 75%         20.00               0.74                 0.76
# max         24.00               1.46                 1.00
